# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url='https://www.daft.ie/property-for-rent/ireland/houses'
soup = BeautifulSoup(url, 'html.parser')
# Out:
# <ipython-input-231-1009a7b9a90e>:2: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(url, 'html.parser')

# %%
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="twitter:app:country" content="IE"/><meta name="twitter:app:name:iphone" content="Daft.ie"/><meta name="twitter:app:id:iphone" content="346547065"/><meta name="twitter:app:url:iphone" content="https://apps.apple.com/ie/app/daft-ie/id346547065"/><meta name="twitter:app:name:ipad" content="Daft.ie"/><meta name="twitter:app:id:ipad" content="346547065"/><meta name="twitter:app:url:ipad" content="https://apps.apple.com/ie/app/daft-ie/id346547065"/><meta name="twitter:app:name:googleplay" content="Daft - Buy, Rent or Share Ireland Real Estate"/><meta name="twitter:app:id:googleplay" content="com.daft.ie"/><meta name="twitter:app:url:googleplay" content="https://play.google.com/store/apps/details?id=com.daft.ie&amp;hl=en"/><script src="https://www.google.com/recaptcha/enterprise.js?render=6LeVIV8lAAAAAIV3iAExz1eHwUtwU3a0OlHfjsmO"></script><meta name=
# ...

# %%
soup=BeautifulSoup(resp.content)

# %%
##ul=soup.find('ul',{'class':"SearchPage__SearchResults-gg133s-3 jGQNan"}) #<ul class="srp-results srp-list clearfix">

# %%
items=ul.find_all('li',{'class':"SearchPage__Result-gg133s-2 djuMQD"}) #<li class="s-item s-item__pl-on-bottom"

# %%
len(items)
# Out:
# 20

# %%
'''info=[]
for item in items:
  record={}
  record['address']=(item.find('h2',{'class':"TitleBlock__Address-sc-1avkvav-8 hCMmam"}))
  record['description']=item.find('div',{'class':"SubUnit__CardInfoContainer-sc-10x486s-9 eamHZU"})
  record['price']=item.find('p',{'class':"SubUnit__Title-sc-10x486s-5 feGTKf"})
  info.append(record)'''


info = []
for item in items:
    record = {}
    record['address'] = item.find('h2', {'class': "TitleBlock__Address-sc-1avkvav-8 hCMmam"})
    record['description'] = item.find('div', {'class': "SubUnit__CardInfoContainer-sc-10x486s-9 eamHZU"})
    record['price'] = float(''.join(filter(str.isdigit, item.find('p', {'class': "SubUnit__Title-sc-10x486s-5 feGTKf"}).text.split('-')[0])) if item.find('p', {'class': "SubUnit__Title-sc-10x486s-5 feGTKf"}) is not None else 0)
    info.append(record)

    print(record['description'])
# Out:
# <div class="SubUnit__CardInfoContainer-sc-10x486s-9 eamHZU"><div class="SubUnit__CardInfo-sc-10x486s-6 gCgIuC" data-testid="sub-line-2-info"><div class="SubUnit__CardInfoItem-sc-10x486s-7 YYbRy">3 Bed<!-- --> · <!-- -->2 Bath<!-- --> · <!-- -->House</div></div></div>
# <div class="SubUnit__CardInfoContainer-sc-10x486s-9 eamHZU"><div class="SubUnit__CardInfo-sc-10x486s-6 gCgIuC" data-testid="sub-line-2-info"><div class="SubUnit__CardInfoItem-sc-10x486s-7 YYbRy">3 Bed<!-- --> · <!-- -->2 Bath<!-- --> · <!-- -->House</div></div></div>
# <div class="SubUnit__CardInfoContainer-sc-10x486s-9 eamHZU"><div class="SubUnit__CardInfo-sc-10x486s-6 gCgIuC" data-testid="sub-line-2-info"><div class="SubUnit__CardInfoItem-sc-10x486s-7 YYbRy">4 Bed<!-- --> · <!-- -->3 Bath<!-- --> · <!-- -->House</div></div></div>
# ...

# %%
#price_element = soup.find('p', {'data-testid': 'sub-title'})
#price_string = price_element.text

# Remove currency symbol, commas, and any non-numeric characters
#price_cleaned = ''.join(filter(str.isdigit, price_string))

# Convert to float
#price_float = float(price_cleaned)

#print(price_float)
#items[0].find('p',{'class':"SubUnit__Title-sc-10x486s-5 feGTKf"}).text.replace('€','').replace(' per month','')

# %%
daftdf=pd.json_normalize(info)
daftdf.head(20)
# Out:
#                                               address  \
# 0   [St Edmunds Avenue , St Edmunds Avenue , Lucan...
# 1   [Hamilton Gardens , Carnlough Road, Cabra, Dub...
# 2   [Griffith Wood, Griffith Avenue, Drumcondra, D...
# 3    [Occu Strand View, Howth Road, Raheny, Dublin 5]
# 4   [Occu Brookwood, St. Brigid's Road, Killester,...
# 5   [Castle Walk, Castle Walk, Cherrywood, Co. Dub...
# 6   [St. Marnocks Bay, Portmarnock, Portmarnock, C...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# ...

# %%
daftdf.describe().T
# Out:
#        count     mean          std  min  25%  50%      75%     max
# price   20.0  1041.05  1697.591528  0.0  0.0  0.0  2727.75  5250.0

# %%
daftdf[daftdf['price']>2000]
# Out:
#                                              address  \
# 0  [St Edmunds Avenue , St Edmunds Avenue , Lucan...
# 1  [Hamilton Gardens , Carnlough Road, Cabra, Dub...
# 2  [Griffith Wood, Griffith Avenue, Drumcondra, D...
# 3   [Occu Strand View, Howth Road, Raheny, Dublin 5]
# 5  [Castle Walk, Castle Walk, Cherrywood, Co. Dub...
# 6  [St. Marnocks Bay, Portmarnock, Portmarnock, C...
#
#                                          description   price
# 0   [[[3 Bed,  ,  · ,  , 2 Bath,  ,  · ,  , House]]]  3000.0
# 1   [[[3 Bed,  ,  · ,  , 2 Bath,  ,  · ,  , House]]]  3350.0
# 2   [[[4 Bed,  ,  · ,  , 3 Bath,  ,  · ,  , House]]]  5250.0
# 3   [[[3 Bed,  ,  · ,  , 3 Bath,  ,  · ,  , House]]]  3384.0
# 5  [[[3 Bed,  ,  · ,  , 2 Bath,  ,  · ,  , House]...  3200.0
# 6  [[[3 Bed,  ,  · ,  , 3 Bath,  ,  · ,  , House]...  2637.0

# %%
import pymongo

values = pymongo.MongoClient("mongodb+srv://happybhadani17:H68iciePn3npbGOO@cluster0.fhbpkfe.mongodb.net/")
mydb = values["daft_house_details_db"]
mycol = mydb["house_details"]

#mydict = { "name": "John", "address": "Highway 37" }
data = daftdf.to_dict(orient='records')
mycol.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-252-50e14e87c354> in <cell line: 9>()
#       7 #mydict = { "name": "John", "address": "Highway 37" }
#       8 data = daftdf.to_dict(orient='records')
# ----> 9 mycol.insert_many(data)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     104                 with _TimeoutContext(timeout):
#     105                     return func(self, *args, **kwargs)
# --> 106         return func(self, *args, **kwargs)
#     107
#     108     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     723         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     724         blk.ops = list(gen())
# ...

# %%
# !python -m pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 31.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# ...
